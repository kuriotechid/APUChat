# %%
from pandasai import SmartDataframe
import pandas as pd
# memasukan csv kedalam dataframe
df = pd.read_csv("~/project/APUChat/workspace/data/data_pencucian_uang.csv")
APU = SmartDataframe(df)

# %%
jml_transaksi = APU.chat("Hitung dan tampilkan mean, median, dan modus untuk kolom 'jumlah transaksi'")
print(jml_transaksi)
# Out:
# Mean: 23623835.07429719, Median: 24534554.5, Modus: [-1000000000.0, -47891604.0, 2177836.0, 2983771.0, 4429868.0, 4839616.0, 6519173.0, 7059517.0, 7366845.0, 10042104.0, 10074352.0, 10809106.0, 12140843.0, 12566942.0, 13942052.0, 14229527.0, 17452740.0, 17898188.0, 20182438.0, 20463645.0, 22273638.0, 22338232.0, 23722452.0, 24527405.0, 24612027.0, 24793045.0, 25830759.0, 26454914.0, 26515146.0, 30514850.0, 31356148.0, 34068157.0, 35797739.0, 36265980.0, 37284532.0, 37532150.0, 38914170.0, 40480243.0, 43011456.0, 44123140.0, 46319500.0, 47553190.0, 48390301.0, 49121158.0, 49205564.0, 1000000000.0]

# %%
histogram = APU.chat("Visualisasikan distribusi 'jenis transaksi' dengan menggunakan box plot")

# %%
jml_transaksi3 = APU.chat("Identifikasi outlier pada 'jumlah transaksi' dengan menggunakan metode IQR'")
jml_transaksi3
# Out:
#             Nama Jenis Transaksi   Jumlah (Rp) Tanggal Transaksi  \
# 118   Pelanggan9         Deposit -3.751363e+07        2022-07-09
# 210   Pelanggan9         Deposit -4.252337e+07        2022-02-15
# 245  Pelanggan10         Deposit  1.000000e+09        2020-01-06
# 256   Pelanggan3     Tarik Tunai -4.915665e+07        2021-08-14
# 328   Pelanggan3             NaN -4.789160e+07        2022-08-31
# 340   Pelanggan5        Transfer -3.321900e+07               NaN
# 345   Pelanggan3        Transfer -4.665407e+07        2020-05-15
# 412   Pelanggan1        Transfer -3.850823e+07        2020-07-18
# 527   Pelanggan3             NaN -4.396578e+07        2022-04-07
# 703   Pelanggan9         Deposit -1.000000e+09        2021-11-21
# 721   Pelanggan9        Transfer -4.750363e+07        2022-04-09
# 796   Pelanggan3             NaN -4.789160e+07        2022-08-31
# 974  Pelanggan10         Deposit  1.000000e+09        2020-01-06
# ...
