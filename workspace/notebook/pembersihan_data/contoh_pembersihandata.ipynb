# %%
from pandasai import SmartDataframe
import pandas as pd
# memasukan csv kedalam dataframe
APU = SmartDataframe("~/project/APUChat/workspace/data/data_pencucian_uang.csv")

# %% [markdown]
# ### cek dupkikasi data

# %%
response = APU.chat("IDENTIFIKASI DAN TAMPILKAN DATA DUPLIKAT DALAM DATASET")
print(response)
# Out:
# 2023-09-18 04:56:04 [INFO] Question: IDENTIFIKASI DAN TAMPILKAN DATA DUPLIKAT DALAM DATASET
# 2023-09-18 04:56:04 [INFO] Running PandasAI with openai LLM...
# 2023-09-18 04:56:04 [INFO] Prompt ID: cd5eed68-b770-4187-b8e6-03b3365be5dc
# 2023-09-18 04:56:14 [INFO]
#                     Code generated:
#                     ```
#                     # TODO import all the dependencies required
# import pandas as pd
#
# # Analyze the data
# # 1. Prepare: Preprocessing and cleaning data if necessary
# # 2. Process: Manipulating data for analysis (grouping, filtering, aggregating, etc.)
# # 3. Analyze: Conducting the actual analysis (if the user asks to create a chart save it to an image in exports/charts/temp_chart.png and do not show the chart.)
# # 4. Output: return a dictionary of:
# # - type (possible values "text", "number", "dataframe", "plot")
# # - value (can be a string, a dataframe or the path of the plot, NOT a dictionary)
# ...

# %%
response = APU.chat("ada berapa baris jumlah data yang hilang?")
print(response)
# Out:
# 2023-09-20 08:34:39 [INFO] Question: ada berapa baris jumlah data yang hilang?
# 2023-09-20 08:34:39 [INFO] Running PandasAI with openai LLM...
# 2023-09-20 08:34:39 [INFO] Prompt ID: ad892294-d7b3-478c-b5c6-28fcdafb84fd
# 2023-09-20 08:34:50 [INFO]
#                     Code generated:
#                     ```
#                     # TODO import all the dependencies required
# import pandas as pd
#
# # Analyze the data
# # 1. Prepare: Preprocessing and cleaning data if necessary
# # 2. Process: Manipulating data for analysis (grouping, filtering, aggregating, etc.)
# # 3. Analyze: Conducting the actual analysis (if the user asks to create a chart save it to an image in exports/charts/temp_chart.png and do not show the chart.)
# # 4. Output: return a dictionary of:
# # - type (possible values "text", "number", "dataframe", "plot")
# # - value (can be a string, a dataframe or the path of the plot, NOT a dictionary)
# ...

# %%
response = APU.chat("identifikasi kolom dengan nilai hilang?")
# Out:
# 2023-09-18 05:29:29 [INFO] Question: identifikasi kolom dengan nilai hilang?
# 2023-09-18 05:29:29 [INFO] Running PandasAI with openai LLM...
# 2023-09-18 05:29:29 [INFO] Prompt ID: a66ff491-a594-4e05-9a4e-ad19d752b863
# 2023-09-18 05:29:38 [INFO]
#                     Code generated:
#                     ```
#                     # TODO import all the dependencies required
# import pandas as pd
#
# # Analyze the data
# # 1. Prepare: Preprocessing and cleaning data if necessary
# # 2. Process: Manipulating data for analysis (grouping, filtering, aggregating, etc.)
# # 3. Analyze: Conducting the actual analysis (if the user asks to create a chart save it to an image in exports/charts/temp_chart.png and do not show the chart.)
# # 4. Output: return a dictionary of:
# # - type (possible values "text", "number", "dataframe", "plot")
# # - value (can be a string, a dataframe or the path of the plot, NOT a dictionary)
# ...

# %%
response = APU.chat("sebutkan presentase nilai yang hilang dalam dataset?")
print(response)
# Out:
# 2023-09-18 11:27:01 [INFO] Question: sebutkan presentase nilai yang hilang dalam dataset?
# 2023-09-18 11:27:01 [INFO] Running PandasAI with openai LLM...
# 2023-09-18 11:27:01 [INFO] Prompt ID: 7617ff4d-c6df-4657-85de-d05364379c88
# 2023-09-18 11:27:13 [INFO]
#                     Code generated:
#                     ```
#                     # TODO import all the dependencies required
# import pandas as pd
#
# # Analyze the data
# # 1. Prepare: Preprocessing and cleaning data if necessary
# # 2. Process: Manipulating data for analysis (grouping, filtering, aggregating, etc.)
# # 3. Analyze: Conducting the actual analysis (if the user asks to create a chart save it to an image in exports/charts/temp_chart.png and do not show the chart.)
# # 4. Output: return a dictionary of:
# # - type (possible values "text", "number", "dataframe", "plot")
# # - value (can be a string, a dataframe or the path of the plot, NOT a dictionary)
# ...

# %%
print(SmartDataframe)
# Out:
# <class 'pandasai.smart_dataframe.SmartDataframe'>
